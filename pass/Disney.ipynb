# %%
# 匯入工具
import requests as req
import json
from bs4 import BeautifulSoup as bs
from pprint import pprint
import pandas as pd


# 打开JSON文件
with open('/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction.json', 'r') as f:
    # 讀取JSON文件資料
    res = json.load(f)

#清空/建立相關欄位list
StandbyTime_list =[]
FacilityName_list =[]
StandbyTime_list.clear()
FacilityName_list.clear()

# 抓出每個元素相關值
for item in res:
    StandbyTime_list.append(
        (item['StandbyTime'])
    )
    FacilityName_list.append(
        (item['FacilityName'])
    )
current_datetime = pd.Timestamp.now().strftime("%Y-%m-%d %H:%M")
print(current_datetime)

# 創建 DataFrame
df = pd.DataFrame()

# 加入欄位
df["FacilityName"] = FacilityName_list
df["StandbyTime"] = StandbyTime_list
df
# Out:
# 2024-05-01 22:32
#                           FacilityName StandbyTime
# 0                         アリスのティーパーティー           5
# 1                       イッツ・ア・スモールワールド           5
# 2                ウエスタンランド・シューティングギャラリー           5
# 3                           ウエスタンリバー鉄道          10
# 4                                オムニバス        None
# 5                               カリブの海賊           5
# 6                         カントリーベア・シアター           5
# 7                        ガジェットのゴーコースター           5
# 8                           キャッスルカルーセル           5
# 9                    グーフィーのペイント＆プレイハウス           5
# 10                  シンデレラのフェアリーテイル・ホール          15
# 11         ジャングルクルーズ：ワイルドライフ・エクスペディション           5
# 12                     スイスファミリー・ツリーハウス           0
# 13         スター・ツアーズ：ザ・アドベンチャーズ・コンティニュー           5
# 14                       スティッチ・エンカウンター          15
# 15                        スプラッシュ・マウンテン           5
# 16                          スペース・マウンテン          45
# 17                      チップとデールのツリーハウス           5
# 18                             トゥーンパーク       False
# 19                           トムソーヤ島いかだ           5
# 20                            ドナルドのボート           5
# 21                 バズ・ライトイヤーのアストロブラスター          30
# 22                       ビッグサンダー・マウンテン           0
# 23                     ビーバーブラザーズのカヌー探険           5
# 24                           ピノキオの冒険旅行          10
# 25                           ピーターパン空の旅          25
# 26                         プーさんのハニーハント           0
# 27                      ベイマックスのハッピーライド          25
# 28                            ペニーアーケード       False
# 29                         ホーンテッドマンション           5
# 30                      ミッキーのフィルハーマジック           5
# 31                               ミニーの家           5
# 32              モンスターズ・インク“ライド＆ゴーシーク！”          50
# 33                  ロジャーラビットのカートゥーンスピン          20
# 34                          白雪姫と七人のこびと          15
# 35                              空飛ぶダンボ           5
# 36                     美女と野獣“魔法のものがたり”          30
# 37                        蒸気船マークトウェイン号          10
# 38  魅惑のチキルーム：スティッチ・プレゼンツ“アロハ・エ・コモ・マイ！”           5

# %%
#正確格式寫入網頁（給第一次用）
import requests as req
import json
import pandas as pd
from fake_useragent import UserAgent

# 隨機取得 User-Agent
ua = UserAgent()

# 自訂標頭
my_headers = {
    'user-agent': ua.chrome
}

# 定义要抓取的 URL
url = "https://www.tokyodisneyresort.jp/_/realtime/tdl_attraction.json?1714465511332"

try:
    # 將自訂標頭加入 GET 請求中
    res = req.get(url, headers=my_headers)
    
    # 如果请求成功
    if res.status_code == 200:
        # 将 JSON 数据解析为 Python 字典
        data = res.json()
        
        # 处理数据格式
        formatted_data = []
        for item in data:
            formatted_data.append({
                'FacilityName': item['FacilityName'],
                'FacilityID': item['FacilityID']
            })

        # 将字典写入 JSON 文件
        with open("/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction_namelist.json", "w") as f:
            json.dump(formatted_data, f, indent=4)  # 使用indent参数进行格式化，缩进4个空格
    else:
        print("Error: Failed to fetch data. Status code:", res.status_code)

except req.Timeout:
    print("Error: Request timed out. Please try again later.")

except req.RequestException as e:
    print("Error:", e)

# %%
#B 嘗試存檔
# 匯入工具
import requests as req
import json
from bs4 import BeautifulSoup as bs
from pprint import pprint
import pandas as pd


# 打开JSON文件
with open('/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction.json', 'r') as f:
    # 讀取JSON文件資料
    res = json.load(f)

#清空/建立相關欄位list
disney_list =[]
disney_list.clear()

#紀錄收集資料時間
current_datetime = pd.Timestamp.now().strftime("%Y-%m-%d %H:%M")

# 抓出每個元素相關值放資料到 list 中
disney_list.append({
        'FacilityName': item['FacilityName'],
        'StandbyTime': item['StandbyTime'],
        'datetime': current_datetime
    })

# %%
#成功儲存檔案
# 匯入工具
import requests as req
import json
from bs4 import BeautifulSoup as bs
from pprint import pprint
import pandas as pd

# 打开JSON文件
with open('/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction.json', 'r') as f:
    # 讀取JSON文件資料
    res = json.load(f)

#清空/建立相關欄位list
disney_list = []
disney_list.clear()

#紀錄收集資料時間
current_datetime = pd.Timestamp.now().strftime("%Y-%m-%d %H:%M")

# 抓出每個元素相關值放資料到 list 中
for item in res:
    disney_list.append({
        'FacilityName': item['FacilityName'],
        'StandbyTime': item['StandbyTime'],
        'FacilityID':item['FacilityID'],
        'UpdateTime':item['UpdateTime'],
        'datetime': current_datetime
    })

# 将列表存储为 JSON 文件
with open('/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/disney_data.json', 'w') as f:
    json.dump(disney_list, f)

# %%
#抓檔案存成json成功/0.2sec/ok
import requests as req
import os, json

# 隨機取得 User-Agent
from fake_useragent import UserAgent
ua = UserAgent()

# 自訂標頭
my_headers = {
    'user-agent': ua.chrome
}

# 定义要抓取的 URL
url = "https://www.tokyodisneyresort.jp/_/realtime/tdl_attraction.json?1714465511332"

# 將自訂標頭加入 GET 請求中
res = req.get(url, headers = my_headers)


try:
    # 將自訂標頭加入 GET 請求中
    res = req.get(url, headers = my_headers)
    
    # 如果请求成功
    if res.status_code == 200:
        # 将 JSON 数据解析为 Python 字典
        data = res.json()

        # 将字典写入 JSON 文件
        with open("/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction_2.json", "w") as f:
            json.dump(data, f)
    else:
        print("Error: Failed to fetch data. Status code:", res.status_code)

except res.Timeout:
    print("Error: Request timed out. Please try again later.")

except res.RequestException as e:
    print("Error:", e)

# %%
#抓檔案存成json成功/避免重複
import requests as req
import os, json

# 隨機取得 User-Agent
from fake_useragent import UserAgent
ua = UserAgent()

# 自訂標頭
my_headers = {
    'user-agent': ua.chrome
}

# 定义要抓取的 URL
url = "https://www.tokyodisneyresort.jp/_/realtime/tdl_attraction.json?1714465511332"

# 將自訂標頭加入 GET 請求中
res = req.get(url, headers = my_headers)

try:
    # 將自訂標頭加入 GET 請求中
    res = req.get(url, headers = my_headers)
    
    # 如果请求成功
    if res.status_code == 200:
        # 将 JSON 数据解析为 Python 字典
        new_data = res.json()

        # 读取现有的 JSON 文件
        file_path = "/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction_2.json"
        if os.path.exists(file_path):
            with open(file_path, "r") as f:
                existing_data = json.load(f)
        else:
            existing_data = []

        # 合并新旧数据并去除重复数据
        combined_data = existing_data.copy()
        for item in new_data:
            if item not in existing_data:
                combined_data.append(item)

        # 将合并后的数据写入 JSON 文件
        with open(file_path, "w") as f:
            json.dump(combined_data, f)
    else:
        print("Error: Failed to fetch data. Status code:", res.status_code)

except res.Timeout:
    print("Error: Request timed out. Please try again later.")

except res.RequestException as e:
    print("Error:", e)

# %%
#抓檔案存成json成功/避免重複/
import requests as req
import os, json
from bs4 import BeautifulSoup as bs
from pprint import pprint
import pandas as pd

# 隨機取得 User-Agent
from fake_useragent import UserAgent
ua = UserAgent()

# 自訂標頭
my_headers = {
    'user-agent': ua.chrome
}

# 定义要抓取的 URL
url = "https://www.tokyodisneyresort.jp/_/realtime/tdl_attraction.json?1714465511332"

# 將自訂標頭加入 GET 請求中
res = req.get(url, headers = my_headers)

try:
    # 將自訂標頭加入 GET 請求中
    res = req.get(url, headers = my_headers)
    
    # 如果请求成功
    if res.status_code == 200:
        # 将 JSON 数据解析为 Python 字典
        new_data = res.json()

        # 读取现有的 JSON 文件
        file_path = "/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction_2.json"
        if os.path.exists(file_path):
            with open(file_path, "r") as f:
                existing_data = json.load(f)
        else:
            existing_data = []

        # 合并新旧数据并去除重复数据
        combined_data = existing_data.copy()
        for item in new_data:
            if item not in existing_data:
                combined_data.append(item)

        # 将合并后的数据写入 JSON 文件
        with open(file_path, "w") as f:
            json.dump(combined_data, f)
    else:
        print("Error: Failed to fetch data. Status code:", res.status_code)

except res.Timeout:
    print("Error: Request timed out. Please try again later.")

except res.RequestException as e:
    print("Error:", e)

# %%
#抓檔案存成json成功/避免重複（語法錯誤）/格式正確
import requests as req
import os
import json
import pandas as pd
from bs4 import BeautifulSoup as bs
from pprint import pprint

# 隨機取得 User-Agent
from fake_useragent import UserAgent
ua = UserAgent()

# 自訂標頭
my_headers = {
    'user-agent': ua.chrome
}

# 定义要抓取的 URL
url = "https://www.tokyodisneyresort.jp/_/realtime/tdl_attraction.json?1714465511332"

try:
    # 將自訂標頭加入 GET 請求中
    res = req.get(url, headers=my_headers)
    
    # 如果请求成功
    if res.status_code == 200:
        # 将 JSON 数据解析为 Python 字典
        new_data = res.json()

        # 读取现有的 JSON 文件
        file_path = "/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction_2.json"
        if os.path.exists(file_path):
            with open(file_path, "r") as f:
                existing_data = json.load(f)
        else:
            existing_data = []

        # 合并新旧数据并去除重复数据
        combined_data = existing_data.copy()
        for item in new_data:
            # 检查是否已存在相同的数据
            exists = False
            for existing_item in existing_data:
                if existing_item['FacilityID'] == item['FacilityID']:
                    exists = True
                    break
            
            # 如果数据不存在，则添加到合并后的数据中
            if not exists:
                combined_data.append({
                    'FacilityName': item['FacilityName'],
                    'StandbyTime': item['StandbyTime'],
                    'FacilityID': item['FacilityID'],
                    'UpdateTime': item['UpdateTime'],
                    'datetime': pd.Timestamp.now().strftime("%Y-%m-%d %H:%M")
                })

        # 将合并后的数据写入 JSON 文件
        with open('/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction_2.json', "w") as f:
            json.dump(combined_data, f)
    else:
        print("Error: Failed to fetch data. Status code:", res.status_code)

except req.Timeout:
    print("Error: Request timed out. Please try again later.")

except req.RequestException as e:
    print("Error:", e)

# %%
#抓檔案存成json成功/避免重複/寫入格式不正確
import requests as req
import os
import json
import pandas as pd
from bs4 import BeautifulSoup as bs
from pprint import pprint

# 隨機取得 User-Agent
from fake_useragent import UserAgent
ua = UserAgent()

# 自訂標頭
my_headers = {
    'user-agent': ua.chrome
}

# 定义要抓取的 URL
url = "https://www.tokyodisneyresort.jp/_/realtime/tdl_attraction.json?1714465511332"

try:
    # 將自訂標頭加入 GET 請求中
    res = req.get(url, headers=my_headers)
    
    # 如果请求成功
    if res.status_code == 200:
        # 将 JSON 数据解析为 Python 字典
        new_data = res.json()

        # 读取现有的 JSON 文件
        file_path = "/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction_2.json"
        if os.path.exists(file_path):
            with open(file_path, "r") as f:
                existing_data = json.load(f)
        else:
            existing_data = []

        # 合并新旧数据并去除重复数据
            combined_data = existing_data.copy()
            for item in new_data:
            # 检查是否已存在相同的数据
                exists = False
                for existing_item in existing_data:
                     if existing_item['FacilityID'] == item['FacilityID'] and existing_item['UpdateTime'] == item['UpdateTime']:
                         exists = True
                         break
            
            # 如果数据不存在，则添加到合并后的数据中
            if not exists:
                combined_data.append({
                    'FacilityName': item['FacilityName'],
                    'StandbyTime': item['StandbyTime'],
                    'FacilityID': item['FacilityID'],
                    'UpdateTime': item['UpdateTime'],
                    'datetime': pd.Timestamp.now().strftime("%Y-%m-%d %H:%M")
                })

        # 将合并后的数据写入 JSON 文件
        with open('/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction_2.json', "w") as f:
            json.dump(combined_data, f)
    else:
        print("Error: Failed to fetch data. Status code:", res.status_code)

except req.Timeout:
    print("Error: Request timed out. Please try again later.")

except req.RequestException as e:
    print("Error:", e)

# %%
#抓檔案存成json成功/避免重複/寫入格式不正確/15min一次
import requests as req
import os
import json
import pandas as pd
from bs4 import BeautifulSoup as bs
from pprint import pprint
import schedule
import time

# 隨機取得 User-Agent
from fake_useragent import UserAgent
ua = UserAgent()

# 自訂標頭
my_headers = {
    'user-agent': ua.chrome
}

# 定义要抓取的 URL
url = "https://www.tokyodisneyresort.jp/_/realtime/tdl_attraction.json?1714465511332"

def job():
    try:
        # 將自訂標頭加入 GET 請求中
        res = req.get(url, headers=my_headers)
        
        # 如果请求成功
        if res.status_code == 200:
            # 将 JSON 数据解析为 Python 字典
            new_data = res.json()

            # 读取现有的 JSON 文件
            file_path = "/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction_2.json"
            if os.path.exists(file_path):
                with open(file_path, "r") as f:
                    existing_data = json.load(f)
            else:
                existing_data = []

            # 合并新旧数据并去除重复数据
            combined_data = existing_data.copy()
            for item in new_data:
            # 检查是否已存在相同的数据
                exists = False
                for existing_item in existing_data:
                     if existing_item['FacilityID'] == item['FacilityID'] and existing_item['UpdateTime'] == item['UpdateTime']:
                         exists = True
                         break
        
                
                # 如果数据不存在，则添加到合并后的数据中
                if not exists:
                    combined_data.append({
                        'FacilityName': item['FacilityName'],
                        'StandbyTime': item['StandbyTime'],
                        'FacilityID': item['FacilityID'],
                        'UpdateTime': item['2'],
                        'datetime': pd.Timestamp.now().strftime("%Y-%m-%d %H:%M")
                    })

            # 将合并后的数据写入 JSON 文件
            with open('/Users/chianlee/Desktop/python_web_scraping/course/cases/disney/tdl_attraction_2.json', "w") as f:
                json.dump(combined_data, f)
        else:
            print("Error: Failed to fetch data. Status code:", res.status_code)

    except req.Timeout:
        print("Error: Request timed out. Please try again later.")

    except req.RequestException as e:
        print("Error:", e)

# 每隔15分钟执行一次任务
schedule.every(15).minutes.do(job)

while True:
    schedule.run_pending()
    time.sleep(1)
